# %%
import sys
sys.executable
# Out:
# '/Users/joerg/opt/anaconda3/envs/python38/bin/python'

# %%
mitosheet.sheet()
# Out:
# MitoWidget(analysis_data_json='{"analysisName": "UUID-a701fa37-e676-483c-b9a2-49e391a9c86d", "code": {"imports…

# %%
# MITO CODE START (DO NOT EDIT)

from mitosheet import * # Import necessary functions from Mito
register_analysis('UUID-a701fa37-e676-483c-b9a2-49e391a9c86d') # Let Mito know which analysis is being run

# Imported /Users/joerg/OneDrive/jupyter_notebooks/finanzen2021/Detail2021-Tabelle 1.csv
import pandas as pd
Detail2021_Tabelle_1_csv = pd.read_csv(r'/Users/joerg/OneDrive/jupyter_notebooks/finanzen2021/Detail2021-Tabelle 1.csv', sep=';')

  
# MITO CODE END (DO NOT EDIT)

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- -----------
# alabaster                          0.7.12
# anaconda-client                    1.8.0
# anaconda-navigator                 1.10.0
# anaconda-project                   0.10.2
# analytics-python                   1.4.0
# anyio                              3.3.4
# appdirs                            1.4.4
# applaunchservices                  0.2.1
# appnope                            0.1.2
# appscript                          1.1.2
# argh                               0.26.2
# argon2-cffi                        21.1.0
# asn1crypto                         1.4.0
# astroid                            2.8.4
# astropy                            4.3.1
# async-generator                    1.10
# atomicwrites                       1.4.0
# attrs                              21.2.0
# autopep8                           1.5.5
# Babel                              2.9.1
# ...

# %%
mitosheet.sheet()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-f6757a510244> in <module>
# ----> 1 mitosheet3.sheet()
#
# NameError: name 'mitosheet3' is not defined

# %%
# MITO CODE START (DO NOT EDIT)

from mitosheet import * # Import necessary functions from Mito
register_analysis('UUID-d8642405-6dbb-4bfe-b92b-06ca067022db') # Let Mito know which analysis is being run

# Imported diagnosis1.csv
import pandas as pd
diagnosis1_csv = pd.read_csv(r'diagnosis1.csv', sep=';')

# Deleted dataframe diagnosis1_csv
del diagnosis1_csv

# Imported /Users/joerg/OneDrive/jupyter_notebooks/finanzen2021/Detail2021-Tabelle 1.csv
import pandas as pd
Detail2021_Tabelle_1_csv = pd.read_csv(r'/Users/joerg/OneDrive/jupyter_notebooks/finanzen2021/Detail2021-Tabelle 1.csv', sep=';')

# Deleted dataframe Detail2021_Tabelle_1_csv
del Detail2021_Tabelle_1_csv

# Imported /Users/joerg/OneDrive/2021/detail2021_csv.csv
import pandas as pd
detail2021_csv_csv = pd.read_csv(r'/Users/joerg/OneDrive/2021/detail2021_csv.csv', sep=';')

# Deleted dataframe detail2021_csv_csv
del detail2021_csv_csv

# Imported /Users/joerg/OneDrive/2021/detail2021_csv.csv
import pandas as pd
detail2021_csv_csv = pd.read_csv(r'/Users/joerg/OneDrive/2021/detail2021_csv.csv', sep=';')

  
# MITO CODE END (DO NOT EDIT)

# %%
jupyterlab --version

# %%
pyhon --version
