# %% [markdown]
# # `Übersicht MPP 2021`

# %% [markdown]
# ### `MAC Mini M1 16GB 1TB SSD`

# %%
from IPython.display import Image
Image(filename='mac_mini_m1_2021.png')

# %%
# !jt -t grade3 -f source -fs 125 -tfs 11 -ofs 12 -T -N -cellw 88% -nfs 115 # -altp -tfs 11

# %%
bruttogehalt = 3777
vorteil_prozent = 0.577
nutzungsrate_brutto = 74.85
marktpreis_mpp = (1467 + 177)
nutzungs_monate = 24
uebernamhme_monate = 4

vorteil_euro = vorteil_prozent * nutzungsrate_brutto
nutzungsrate_netto = nutzungsrate_brutto - vorteil_euro

gesamt_preis = nutzungsrate_netto * nutzungs_monate
uebernahme_preis = gesamt_preis + 4*nutzungsrate_brutto

ersparnis =  marktpreis_mpp - uebernahme_preis
ersparnis_prozent = 100-(uebernahme_preis/marktpreis_mpp*100)

nettogehalt_alt = 1888
nettogehalt_neu = nettogehalt_alt - nutzungsrate_netto

print('Bruttogehalt [€]: \t', bruttogehalt, '€' )
print('Nutzungsrate brutto: \t', nutzungsrate_brutto, '€')
print('Vorteil_prozent: \t', round(vorteil_prozent*100,2), '%')
print('Vorteil [€]: \t\t', round(vorteil_euro, 2), '€')
print('Nutzungsrate_netto [€]: ', round(nutzungsrate_netto, 2), '€')
print('Marktpreis lt. MPP: \t', marktpreis_mpp, '€')
print('Gesamtpreis [€]: \t', round(gesamt_preis, 2), '€')
print('Übernahme_preis [€]: \t', round(uebernahme_preis, 2), '€')
print('Erparnis [€]: \t\t', round(ersparnis, 2), '€')
print('Erparnis_prozent [€]: \t', round(ersparnis_prozent, 2), '%')
print('Nettogehalt_alt: \t', round(nettogehalt_alt,2), '€')
print('Nettogehalt_neu: \t', round(nettogehalt_neu,2), '€')



print('-----')
#Print_ausgabe
print('Vorteil [€] \t\t = ',round(vorteil_prozent*100,2) ,'%' ,'*',nutzungsrate_brutto,'€','=',round(vorteil_euro,2),'€')
print('Vorteil_netto [€] \t = ',round(nutzungsrate_brutto,2) ,'€' ,'-',round(vorteil_euro,2),'€','=',round(nutzungsrate_netto,2),'€')
print('Gesamtpreis [€] \t = ',round(nutzungsrate_netto,2) ,'€' ,'*',round(nutzungs_monate,2),'Monate','=',round(gesamt_preis,2),'€')
print('Übernahmepreis [€] \t = ',round(gesamt_preis,2) ,'€' ,'+',round(nutzungsrate_brutto,2),'€' , '*', round(uebernamhme_monate,2),'Monate','=',round(uebernahme_preis,2),'€')
print('Ersparnis [€] \t\t = ',round(marktpreis_mpp,2) ,'€' ,'-',round(uebernahme_preis,2),'€' , '=', round(ersparnis,2),'€','=',round(ersparnis_prozent,2),'%')
print('Nettogehalt_alt [€] \t = ',round(nettogehalt_alt,2) ,'€')
print('Nettogehalt_neu [€] \t = ',round(nettogehalt_alt,2) ,'€' ,'-', round(nutzungsrate_netto,2), '€', '=', round(nettogehalt_neu,2), '€')
# Out:
# Bruttogehalt [€]: 	 3777 €
# Nutzungsrate brutto: 	 74.85 €
# Vorteil_prozent: 	 57.7 %
# Vorteil [€]: 		 43.19 €
# Nutzungsrate_netto [€]:  31.66 €
# Marktpreis lt. MPP: 	 1644 €
# Gesamtpreis [€]: 	 759.88 €
# Übernahme_preis [€]: 	 1059.28 €
# Erparnis [€]: 		 584.72 €
# Erparnis_prozent [€]: 	 35.57 %
# Nettogehalt_alt: 	 1888 €
# Nettogehalt_neu: 	 1856.34 €
# -----
# Vorteil [€] 		 =  57.7 % * 74.85 € = 43.19 €
# Vorteil_netto [€] 	 =  74.85 € - 43.19 € = 31.66 €
# Gesamtpreis [€] 	 =  31.66 € * 24 Monate = 759.88 €
# Übernahmepreis [€] 	 =  759.88 € + 74.85 € * 4 Monate = 1059.28 €
# Ersparnis [€] 		 =  1644 € - 1059.28 € = 584.72 € = 35.57 %
# Nettogehalt_alt [€] 	 =  1888 €
# Nettogehalt_neu [€] 	 =  1888 € - 31.66 € = 1856.34 €

# %% [markdown]
# ### `Mac Mini 2019`

# %%
bruttogehalt = 3677
vorteil_prozent = 0.601
nutzungsrate_brutto = 70.80
marktpreis_mpp = (1231 + 177)
nettogehalt_alt = 1762.52
nutzungs_monate = 24
uebernamhme_monate = 4

vorteil_euro = vorteil_prozent * nutzungsrate_brutto
nutzungsrate_netto = nutzungsrate_brutto - vorteil_euro

gesamt_preis = nutzungsrate_netto * nutzungs_monate
uebernahme_preis = gesamt_preis + 4*nutzungsrate_brutto

ersparnis =  marktpreis_mpp - uebernahme_preis
ersparnis_prozent = 100-(uebernahme_preis/marktpreis_mpp*100)


nettogehalt_neu = nettogehalt_alt - nutzungsrate_netto

print('Bruttogehalt [€]: \t', bruttogehalt, '€' )
print('Nutzungsrate brutto: \t', nutzungsrate_brutto, '€')
print('Vorteil_prozent: \t', round(vorteil_prozent*100,2), '%')
print('Vorteil [€]: \t\t', round(vorteil_euro, 2), '€')
print('Nutzungsrate_netto [€]: ', round(nutzungsrate_netto, 2), '€')
print('Marktpreis lt. MPP: \t', marktpreis_mpp, '€')
print('Gesamtpreis [€]: \t', round(gesamt_preis, 2), '€')
print('Übernahme_preis [€]: \t', round(uebernahme_preis, 2), '€')
print('Erparnis [€]: \t\t', round(ersparnis, 2), '€')
print('Erparnis_prozent [€]: \t', round(ersparnis_prozent, 2), '%')
print('Nettogehalt_alt: \t', round(nettogehalt_alt,2), '€')
print('Nettogehalt_neu: \t', round(nettogehalt_neu,2), '€')



print('-----')
#Print_ausgabe
print('Vorteil [€] \t\t = ',round(vorteil_prozent*100,2) ,'%' ,'*',nutzungsrate_brutto,'€','=',round(vorteil_euro,2),'€')
print('Vorteil_netto [€] \t = ',round(nutzungsrate_brutto,2) ,'€' ,'-',round(vorteil_euro,2),'€','=',round(nutzungsrate_netto,2),'€')
print('Gesamtpreis [€] \t = ',round(nutzungsrate_netto,2) ,'€' ,'*',round(nutzungs_monate,2),'Monate','=',round(gesamt_preis,2),'€')
print('Übernahmepreis [€] \t = ',round(gesamt_preis,2) ,'€' ,'+',round(nutzungsrate_brutto,2),'€' , '*', round(uebernamhme_monate,2),'Monate','=',round(uebernahme_preis,2),'€')
print('Ersparnis [€] \t\t = ',round(marktpreis_mpp,2) ,'€' ,'-',round(uebernahme_preis,2),'€' , '=', round(ersparnis,2),'€','=',round(ersparnis_prozent,2),'%')
print('Nettogehalt_alt [€] \t = ',round(nettogehalt_alt,2) ,'€')
print('Nettogehalt_neu [€] \t = ',round(nettogehalt_alt,2) ,'€' ,'-', round(nutzungsrate_netto,2), '€', '=', round(nettogehalt_neu,2), '€')
# Out:
# Bruttogehalt [€]: 	 3677 €
# Nutzungsrate brutto: 	 70.8 €
# Vorteil_prozent: 	 60.1 %
# Vorteil [€]: 		 42.55 €
# Nutzungsrate_netto [€]:  28.25 €
# Marktpreis lt. MPP: 	 1408 €
# Gesamtpreis [€]: 	 677.98 €
# Übernahme_preis [€]: 	 961.18 €
# Erparnis [€]: 		 446.82 €
# Erparnis_prozent [€]: 	 31.73 %
# Nettogehalt_alt: 	 1762.52 €
# Nettogehalt_neu: 	 1734.27 €
# -----
# Vorteil [€] 		 =  60.1 % * 70.8 € = 42.55 €
# Vorteil_netto [€] 	 =  70.8 € - 42.55 € = 28.25 €
# Gesamtpreis [€] 	 =  28.25 € * 24 Monate = 677.98 €
# Übernahmepreis [€] 	 =  677.98 € + 70.8 € * 4 Monate = 961.18 €
# Ersparnis [€] 		 =  1408 € - 961.18 € = 446.82 € = 31.73 %
# Nettogehalt_alt [€] 	 =  1762.52 €
# Nettogehalt_neu [€] 	 =  1762.52 € - 28.25 € = 1734.27 €

# %% [markdown]
# ***

# %% [markdown]
# ## `Apple Watch Series 6 LTE , 44MM Edelstahlgehäuse , Sportarmband`

# %%
Image(filename='apple_watch_edelstahl_sportarmband_2021.png', width = 600, height = 300)

# %%
bruttogehalt = 3777
vorteil_prozent = 0.577
nutzungsrate_brutto = 39.28
marktpreis_mpp = (779 + 80)
nutzungs_monate = 24
uebernamhme_monate = 4

vorteil_euro = vorteil_prozent * nutzungsrate_brutto
nutzungsrate_netto = nutzungsrate_brutto - vorteil_euro

gesamt_preis = nutzungsrate_netto * nutzungs_monate
uebernahme_preis = gesamt_preis + 4*nutzungsrate_brutto

ersparnis =  marktpreis_mpp - uebernahme_preis
ersparnis_prozent = 100-(uebernahme_preis/marktpreis_mpp*100)

nettogehalt_alt = 1888
nettogehalt_neu = nettogehalt_alt - nutzungsrate_netto

print('Bruttogehalt [€]: \t', bruttogehalt, '€' )
print('Nutzungsrate brutto: \t', nutzungsrate_brutto, '€')
print('Vorteil_prozent: \t', round(vorteil_prozent*100,2), '%')
print('Vorteil [€]: \t\t', round(vorteil_euro, 2), '€')
print('Nutzungsrate_netto [€]: ', round(nutzungsrate_netto, 2), '€')
print('Marktpreis lt. MPP: \t', marktpreis_mpp, '€')
print('Gesamtpreis [€]: \t', round(gesamt_preis, 2), '€')
print('Übernahme_preis [€]: \t', round(uebernahme_preis, 2), '€')
print('Erparnis [€]: \t\t', round(ersparnis, 2), '€')
print('Erparnis_prozent [€]: \t', round(ersparnis_prozent, 2), '%')
print('Nettogehalt_alt: \t', round(nettogehalt_alt,2), '€')
print('Nettogehalt_neu: \t', round(nettogehalt_neu,2), '€')



print('-----')
#Print_ausgabe
print('Vorteil [€] \t\t = ',round(vorteil_prozent*100,2) ,'%' ,'*',nutzungsrate_brutto,'€','=',round(vorteil_euro,2),'€')
print('Vorteil_netto [€] \t = ',round(nutzungsrate_brutto,2) ,'€' ,'-',round(vorteil_euro,2),'€','=',round(nutzungsrate_netto,2),'€')
print('Gesamtpreis [€] \t = ',round(nutzungsrate_netto,2) ,'€' ,'*',round(nutzungs_monate,2),'Monate','=',round(gesamt_preis,2),'€')
print('Übernahmepreis [€] \t = ',round(gesamt_preis,2) ,'€' ,'+',round(nutzungsrate_brutto,2),'€' , '*', round(uebernamhme_monate,2),'Monate','=',round(uebernahme_preis,2),'€')
print('Ersparnis [€] \t\t = ',round(marktpreis_mpp,2) ,'€' ,'-',round(uebernahme_preis,2),'€' , '=', round(ersparnis,2),'€','=',round(ersparnis_prozent,2),'%')
print('Nettogehalt_alt [€] \t = ',round(nettogehalt_alt,2) ,'€')
print('Nettogehalt_neu [€] \t = ',round(nettogehalt_alt,2) ,'€' ,'-', round(nutzungsrate_netto,2), '€', '=', round(nettogehalt_neu,2), '€')
# Out:
# Bruttogehalt [€]: 	 3777 €
# Nutzungsrate brutto: 	 39.28 €
# Vorteil_prozent: 	 57.7 %
# Vorteil [€]: 		 22.66 €
# Nutzungsrate_netto [€]:  16.62 €
# Marktpreis lt. MPP: 	 859 €
# Gesamtpreis [€]: 	 398.77 €
# Übernahme_preis [€]: 	 555.89 €
# Erparnis [€]: 		 303.11 €
# Erparnis_prozent [€]: 	 35.29 %
# Nettogehalt_alt: 	 1888 €
# Nettogehalt_neu: 	 1871.38 €
# -----
# Vorteil [€] 		 =  57.7 % * 39.28 € = 22.66 €
# Vorteil_netto [€] 	 =  39.28 € - 22.66 € = 16.62 €
# Gesamtpreis [€] 	 =  16.62 € * 24 Monate = 398.77 €
# Übernahmepreis [€] 	 =  398.77 € + 39.28 € * 4 Monate = 555.89 €
# Ersparnis [€] 		 =  859 € - 555.89 € = 303.11 € = 35.29 %
# Nettogehalt_alt [€] 	 =  1888 €
# Nettogehalt_neu [€] 	 =  1888 € - 16.62 € = 1871.38 €

# %% [markdown]
# ****

# %% [markdown]
# ## `Apple MacBook Air M1 8Core 16GB 512SD - Angebot April 2022`

# %%
Image(filename='apple_macbook_m1_8core_air_16GB_512SSD_Nov_2020.png', width = 600, height = 300)

# %%
bruttogehalt = 3847
vorteil_prozent = 0.576
nutzungsrate_brutto = 81.20
marktpreis_mpp = (1607 + 177)
nutzungs_monate = 24
uebernamhme_monate = 4

vorteil_euro = vorteil_prozent * nutzungsrate_brutto
nutzungsrate_netto = nutzungsrate_brutto - vorteil_euro

gesamt_preis = nutzungsrate_netto * nutzungs_monate
uebernahme_preis = gesamt_preis + 4*nutzungsrate_brutto

ersparnis =  marktpreis_mpp - uebernahme_preis
ersparnis_prozent = 100-(uebernahme_preis/marktpreis_mpp*100)

nettogehalt_alt = 1924
nettogehalt_neu = nettogehalt_alt - nutzungsrate_netto

print('Bruttogehalt [€]: \t', bruttogehalt, '€' )
print('Nutzungsrate brutto: \t', nutzungsrate_brutto, '€')
print('Vorteil_prozent: \t', round(vorteil_prozent*100,2), '%')
print('Vorteil [€]: \t\t', round(vorteil_euro, 2), '€')
print('Nutzungsrate_netto [€]: ', round(nutzungsrate_netto, 2), '€')
print('Marktpreis lt. MPP: \t', marktpreis_mpp, '€')
print('Gesamtpreis [€]: \t', round(gesamt_preis, 2), '€')
print('Übernahme_preis [€]: \t', round(uebernahme_preis, 2), '€')
print('Erparnis [€]: \t\t', round(ersparnis, 2), '€')
print('Erparnis_prozent [€]: \t', round(ersparnis_prozent, 2), '%')
print('Nettogehalt_alt: \t', round(nettogehalt_alt,2), '€')
print('Nettogehalt_neu: \t', round(nettogehalt_neu,2), '€')



print('-----')
#Print_ausgabe
print('Vorteil [€] \t\t = ',round(vorteil_prozent*100,2) ,'%' ,'*',nutzungsrate_brutto,'€','=',round(vorteil_euro,2),'€')
print('Vorteil_netto [€] \t = ',round(nutzungsrate_brutto,2) ,'€' ,'-',round(vorteil_euro,2),'€','=',round(nutzungsrate_netto,2),'€')
print('Gesamtpreis [€] \t = ',round(nutzungsrate_netto,2) ,'€' ,'*',round(nutzungs_monate,2),'Monate','=',round(gesamt_preis,2),'€')
print('Übernahmepreis [€] \t = ',round(gesamt_preis,2) ,'€' ,'+',round(nutzungsrate_brutto,2),'€' , '*', round(uebernamhme_monate,2),'Monate','=',round(uebernahme_preis,2),'€')
print('Ersparnis [€] \t\t = ',round(marktpreis_mpp,2) ,'€' ,'-',round(uebernahme_preis,2),'€' , '=', round(ersparnis,2),'€','=',round(ersparnis_prozent,2),'%')
print('Nettogehalt_alt [€] \t = ',round(nettogehalt_alt,2) ,'€')
print('Nettogehalt_neu [€] \t = ',round(nettogehalt_alt,2) ,'€' ,'-', round(nutzungsrate_netto,2), '€', '=', round(nettogehalt_neu,2), '€')
# Out:
# Bruttogehalt [€]: 	 3847 €
# Nutzungsrate brutto: 	 81.2 €
# Vorteil_prozent: 	 57.6 %
# Vorteil [€]: 		 46.77 €
# Nutzungsrate_netto [€]:  34.43 €
# Marktpreis lt. MPP: 	 1784 €
# Gesamtpreis [€]: 	 826.29 €
# Übernahme_preis [€]: 	 1151.09 €
# Erparnis [€]: 		 632.91 €
# Erparnis_prozent [€]: 	 35.48 %
# Nettogehalt_alt: 	 1924 €
# Nettogehalt_neu: 	 1889.57 €
# -----
# Vorteil [€] 		 =  57.6 % * 81.2 € = 46.77 €
# Vorteil_netto [€] 	 =  81.2 € - 46.77 € = 34.43 €
# Gesamtpreis [€] 	 =  34.43 € * 24 Monate = 826.29 €
# Übernahmepreis [€] 	 =  826.29 € + 81.2 € * 4 Monate = 1151.09 €
# Ersparnis [€] 		 =  1784 € - 1151.09 € = 632.91 € = 35.48 %
# Nettogehalt_alt [€] 	 =  1924 €
# Nettogehalt_neu [€] 	 =  1924 € - 34.43 € = 1889.57 €

# %% [markdown]
# ***

# %% [markdown]
# ## `Apple iPhone 13 Mini 256GB - Angebot April 2022`

# %%
bruttogehalt = 3847
vorteil_prozent = 0.576
nutzungsrate_brutto = 45.58
marktpreis_mpp = (919 + 78)
nutzungs_monate = 24
uebernamhme_monate = 4

vorteil_euro = vorteil_prozent * nutzungsrate_brutto
nutzungsrate_netto = nutzungsrate_brutto - vorteil_euro

gesamt_preis = nutzungsrate_netto * nutzungs_monate
uebernahme_preis = gesamt_preis + 4*nutzungsrate_brutto

ersparnis =  marktpreis_mpp - uebernahme_preis
ersparnis_prozent = 100-(uebernahme_preis/marktpreis_mpp*100)

nettogehalt_alt = 1924
nettogehalt_neu = nettogehalt_alt - nutzungsrate_netto

print('Bruttogehalt [€]: \t', bruttogehalt, '€' )
print('Nutzungsrate brutto: \t', nutzungsrate_brutto, '€')
print('Vorteil_prozent: \t', round(vorteil_prozent*100,2), '%')
print('Vorteil [€]: \t\t', round(vorteil_euro, 2), '€')
print('Nutzungsrate_netto [€]: ', round(nutzungsrate_netto, 2), '€')
print('Marktpreis lt. MPP: \t', marktpreis_mpp, '€')
print('Gesamtpreis [€]: \t', round(gesamt_preis, 2), '€')
print('Übernahme_preis [€]: \t', round(uebernahme_preis, 2), '€')
print('Erparnis [€]: \t\t', round(ersparnis, 2), '€')
print('Erparnis_prozent [€]: \t', round(ersparnis_prozent, 2), '%')
print('Nettogehalt_alt: \t', round(nettogehalt_alt,2), '€')
print('Nettogehalt_neu: \t', round(nettogehalt_neu,2), '€')



print('-----')
#Print_ausgabe
print('Vorteil [€] \t\t = ',round(vorteil_prozent*100,2) ,'%' ,'*',nutzungsrate_brutto,'€','=',round(vorteil_euro,2),'€')
print('Vorteil_netto [€] \t = ',round(nutzungsrate_brutto,2) ,'€' ,'-',round(vorteil_euro,2),'€','=',round(nutzungsrate_netto,2),'€')
print('Gesamtpreis [€] \t = ',round(nutzungsrate_netto,2) ,'€' ,'*',round(nutzungs_monate,2),'Monate','=',round(gesamt_preis,2),'€')
print('Übernahmepreis [€] \t = ',round(gesamt_preis,2) ,'€' ,'+',round(nutzungsrate_brutto,2),'€' , '*', round(uebernamhme_monate,2),'Monate','=',round(uebernahme_preis,2),'€')
print('Ersparnis [€] \t\t = ',round(marktpreis_mpp,2) ,'€' ,'-',round(uebernahme_preis,2),'€' , '=', round(ersparnis,2),'€','=',round(ersparnis_prozent,2),'%')
print('Nettogehalt_alt [€] \t = ',round(nettogehalt_alt,2) ,'€')
print('Nettogehalt_neu [€] \t = ',round(nettogehalt_alt,2) ,'€' ,'-', round(nutzungsrate_netto,2), '€', '=', round(nettogehalt_neu,2), '€')
# Out:
# Bruttogehalt [€]: 	 3847 €
# Nutzungsrate brutto: 	 45.58 €
# Vorteil_prozent: 	 57.6 %
# Vorteil [€]: 		 26.25 €
# Nutzungsrate_netto [€]:  19.33 €
# Marktpreis lt. MPP: 	 997 €
# Gesamtpreis [€]: 	 463.82 €
# Übernahme_preis [€]: 	 646.14 €
# Erparnis [€]: 		 350.86 €
# Erparnis_prozent [€]: 	 35.19 %
# Nettogehalt_alt: 	 1924 €
# Nettogehalt_neu: 	 1904.67 €
# -----
# Vorteil [€] 		 =  57.6 % * 45.58 € = 26.25 €
# Vorteil_netto [€] 	 =  45.58 € - 26.25 € = 19.33 €
# Gesamtpreis [€] 	 =  19.33 € * 24 Monate = 463.82 €
# Übernahmepreis [€] 	 =  463.82 € + 45.58 € * 4 Monate = 646.14 €
# Ersparnis [€] 		 =  997 € - 646.14 € = 350.86 € = 35.19 %
# Nettogehalt_alt [€] 	 =  1924 €
# Nettogehalt_neu [€] 	 =  1924 € - 19.33 € = 1904.67 €

# %%
1607+177
# Out:
# 1784

# %%
81.2/74.3
# Out:
# 1.0928667563930015

# %%
1784/24
# Out:
# 74.33333333333333

# %%
(1959+180)/24*1.1
# Out:
# 98.03750000000001

# %%
34.43/81.2
# Out:
# 0.42401477832512313

# %%
99*0.42
# Out:
# 41.58

# %%
41.58*24
# Out:
# 997.92
