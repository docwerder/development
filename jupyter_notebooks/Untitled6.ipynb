# %%
import mitosheet

# %%
mitosheet.sheet()
# Out:
# MitoWidget(analysis_data_json='{"analysisName": "UUID-28faa788-2c7e-4fed-acc3-ce17ff778f44", "code": {"imports…

# %%
# MITO CODE START (DO NOT EDIT)

from mitosheet import * # Import necessary functions from Mito
register_analysis('UUID-28faa788-2c7e-4fed-acc3-ce17ff778f44') # Let Mito know which analysis is being run

# Imported /Users/joerg/OneDrive/jupyter_notebooks/mito/Mito Tutorial Data/Zipcode-Data.csv
import pandas as pd
Zipcode_Data_csv = pd.read_csv(r'/Users/joerg/OneDrive/jupyter_notebooks/mito/Mito Tutorial Data/Zipcode-Data.csv')

# Imported /Users/joerg/OneDrive/jupyter_notebooks/mito/Mito Tutorial Data/Airport-Pets.csv
import pandas as pd
Airport_Pets_csv = pd.read_csv(r'/Users/joerg/OneDrive/jupyter_notebooks/mito/Mito Tutorial Data/Airport-Pets.csv')

  
# MITO CODE END (DO NOT EDIT)

# %%
conda list
# Out:
# # packages in environment at /opt/anaconda3/envs/python39:
# #
# # Name                    Version                   Build  Channel
# analytics-python          1.4.0                    pypi_0    pypi
# anyio                     2.2.0            py39h6e9494a_0    conda-forge
# appnope                   0.1.2            py39h6e9494a_1    conda-forge
# argon2-cffi               20.1.0           py39hcbf5805_2    conda-forge
# async_generator           1.10                       py_0    conda-forge
# attrs                     20.3.0             pyhd3deb0d_0    conda-forge
# babel                     2.9.0              pyhd3deb0d_0    conda-forge
# backcall                  0.2.0              pyh9f0ad1d_0    conda-forge
# backoff                   1.10.0                   pypi_0    pypi
# backports                 1.0                        py_2    conda-forge
# backports.functools_lru_cache 1.6.3              pyhd8ed1ab_0    conda-forge
# ...

# %%
hghg
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-4f041a68c883> in <module>
# ----> 1 hghg
#
# NameError: name 'hghg' is not defined
