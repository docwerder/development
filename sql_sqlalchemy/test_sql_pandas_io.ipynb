# %%
import pandas as pd
import sqlite3
anomaly_path = '/Users/joerg/repos/development/sql/AnomalyDatabase/anomaly_database.db'
connection = sqlite3.connect(anomaly_path)
cursor = connection.cursor()

# %%
# Out:
# ...
#   Using cached mariadb-1.1.3.tar.gz (80 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Users/joerg/opt/anaconda3/envs/python38/bin/python -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/z2/_gyyb63x4pv6zvl1bd53ryg00000gn/T/pip-install-2gp4disf/mariadb_742eead4e8b6470482b83aa34682d559/setup.py'"'"'; __file__='"'"'/private/var/folders/z2/_gyyb63x4pv6zvl1bd53ryg00000gn/T/pip-install-2gp4disf/mariadb_742eead4e8b6470482b83aa34682d559/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/z2/_gyyb63x4pv6zvl1bd53ryg00000gn/T/pip-pip-egg-info-k9pyp0pd
#          cwd: /private/var/folders/z2/_gyyb63x4pv6zvl1bd53ryg00000gn/T/pip-install-2gp4disf/mariadb_742eead4e8b6470482b83aa34682d559/
#     Complete output (18 lines):
#     /bin/sh: mariadb_config: command not found
# ...

# %%
import mariadb
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 import mariadb
#
# ModuleNotFoundError: No module named 'mariadb'

# %%
import pandas.io.sql
from sqlalchemy import create_engine

# %%
engine = create_engine("mariadb:///?User=db_user&;Password=pax123&Database=werderdb&Server=192.168.178.48&Port=3306")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 engine = create_engine("mariadb:///?User=db_user&;Password=pax123&Database=werderdb&Server=192.168.178.48&Port=3306")
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/deprecations.py:309, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     302     if m in kwargs:
#     303         _warn_with_version(
#     304             messages[m],
#     305             versions[m],
#     306             version_warnings[m],
#     307             stacklevel=3,
#     308         )
# --> 309 return fn(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/create.py:560, in create_engine(url, **kwargs)
#     558         if k in kwargs:
# ...

# %%
server = "192.168.178.48:3306"
